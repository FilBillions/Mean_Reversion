# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='^vix_1d_9-MA_percent_of_equity_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1000
# --------------------------------------------------
# 90% Confidence Interval: (63.4578, 73.1935)
# 95% Confidence Interval: (62.5252, 74.126)
# 98% Confidence Interval: (61.4409, 75.2103)
# 99% Confidence Interval: (61.4409, 75.2103)
# --------------------------------------------------
# Model Results:
# Model Mean: 68.33%
# Model Std: 93.59%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 9.9%
# SPY Buy/Hold Std: 16.77%
# --------------------------------------------------

# %%
sharpe_hist(import_csv, buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1000
# --------------------------------------------------
# 90% Confidence Interval: (1.1298, 1.1834)
# 95% Confidence Interval: (1.1246, 1.1886)
# 98% Confidence Interval: (1.1187, 1.1945)
# 99% Confidence Interval: (1.1187, 1.1945)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 1.1566
# Model Std: 0.5158
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.8427
# SPY Std: 0.9514
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 49
# --------------------------------------------------
# 90% Confidence Interval: (21.9234, 45.8786)
# 95% Confidence Interval: (19.6289, 48.1732)
# 98% Confidence Interval: (16.9609, 50.8411)
# 99% Confidence Interval: (16.9609, 50.8411)
# --------------------------------------------------
# Model Results:
# Model Mean: 33.9%
# Model Std: 50.97%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -17.43%
# Buy/Hold Std: 10.68%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: -9.7%
# SPY Buy/Hold Std: 3.91%
# --------------------------------------------------
# --------------------------------------------------
# n = 49
# --------------------------------------------------
# 90% Confidence Interval: (0.6958, 1.0261)
# 95% Confidence Interval: (0.6642, 1.0577)
# 98% Confidence Interval: (0.6274, 1.0945)
# 99% Confidence Interval: (0.6274, 1.0945)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.8609
# Model Std: 0.7028
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.2454
# Buy/Hold Std: 0.1377
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: -0.3468
# SPY Std: 0.2379
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 264
# --------------------------------------------------
# 90% Confidence Interval: (54.7378, 78.7089)
# 95% Confidence Interval: (52.4417, 81.0051)
# 98% Confidence Interval: (49.7719, 83.6748)
# 99% Confidence Interval: (49.7719, 83.6748)
# --------------------------------------------------
# Model Results:
# Model Mean: 66.72%
# Model Std: 118.4%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 38.62%
# Buy/Hold Std: 37.26%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 13.15%
# SPY Buy/Hold Std: 7.48%
# --------------------------------------------------
# --------------------------------------------------
# n = 264
# --------------------------------------------------
# 90% Confidence Interval: (1.082, 1.1802)
# 95% Confidence Interval: (1.0726, 1.1896)
# 98% Confidence Interval: (1.0617, 1.2005)
# 99% Confidence Interval: (1.0617, 1.2005)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 1.1311
# Model Std: 0.4849
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.8296
# Buy/Hold Std: 0.2063
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.9708
# SPY Std: 0.5785
# --------------------------------------------------
