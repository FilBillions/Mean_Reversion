# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='backtest_output/^vix_1d_50-MA_cash_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1005
# --------------------------------------------------
# 90% Confidence Interval: (31.5399, 33.8352)
# 95% Confidence Interval: (31.32, 34.0551)
# 98% Confidence Interval: (31.0644, 34.3107)
# 99% Confidence Interval: (31.0644, 34.3107)
# --------------------------------------------------
# Model Results:
# Model Mean: 32.69%
# Model Std: 22.12%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 8.92%
# SPY Buy/Hold Std: 16.86%
# --------------------------------------------------

# %%
sharpe_hist(import_csv, buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1005
# --------------------------------------------------
# 90% Confidence Interval: (0.9786, 1.0181)
# 95% Confidence Interval: (0.9748, 1.0219)
# 98% Confidence Interval: (0.9704, 1.0263)
# 99% Confidence Interval: (0.9704, 1.0263)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.9983
# Model Std: 0.381
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.7899
# SPY Std: 0.952
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 55
# --------------------------------------------------
# 90% Confidence Interval: (19.7891, 28.852)
# 95% Confidence Interval: (18.921, 29.7201)
# 98% Confidence Interval: (17.9116, 30.7295)
# 99% Confidence Interval: (17.9116, 30.7295)
# --------------------------------------------------
# Model Results:
# Model Mean: 24.32%
# Model Std: 20.43%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -17.22%
# Buy/Hold Std: 11.25%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: -9.05%
# SPY Buy/Hold Std: 4.33%
# --------------------------------------------------
# --------------------------------------------------
# n = 55
# --------------------------------------------------
# 90% Confidence Interval: (0.744, 0.9083)
# 95% Confidence Interval: (0.7282, 0.9241)
# 98% Confidence Interval: (0.7099, 0.9424)
# 99% Confidence Interval: (0.7099, 0.9424)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.8262
# Model Std: 0.3705
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.2352
# Buy/Hold Std: 0.168
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: -0.3125
# SPY Std: 0.2177
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 286
# --------------------------------------------------
# 90% Confidence Interval: (33.8355, 38.3395)
# 95% Confidence Interval: (33.4041, 38.7709)
# 98% Confidence Interval: (32.9025, 39.2725)
# 99% Confidence Interval: (32.9025, 39.2725)
# --------------------------------------------------
# Model Results:
# Model Mean: 36.09%
# Model Std: 23.15%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 41.65%
# Buy/Hold Std: 37.03%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 12.42%
# SPY Buy/Hold Std: 7.07%
# --------------------------------------------------
# --------------------------------------------------
# n = 286
# --------------------------------------------------
# 90% Confidence Interval: (0.9301, 1.0014)
# 95% Confidence Interval: (0.9232, 1.0082)
# 98% Confidence Interval: (0.9153, 1.0162)
# 99% Confidence Interval: (0.9153, 1.0162)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.9657
# Model Std: 0.3668
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.8503
# Buy/Hold Std: 0.1986
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.9332
# SPY Std: 0.594
# --------------------------------------------------
