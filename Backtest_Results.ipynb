# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='backtest_output/^vix_1d_21-MA_percent_of_equity_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1005
# --------------------------------------------------
# 90% Confidence Interval: (64.9711, 72.6721)
# 95% Confidence Interval: (64.2335, 73.4097)
# 98% Confidence Interval: (63.3758, 74.2674)
# 99% Confidence Interval: (63.3758, 74.2674)
# --------------------------------------------------
# Model Results:
# Model Mean: 68.82%
# Model Std: 74.21%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 9.82%
# SPY Buy/Hold Std: 17.1%
# --------------------------------------------------

# %%
sharpe_hist(import_csv, buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1005
# --------------------------------------------------
# 90% Confidence Interval: (1.0001, 1.0419)
# 95% Confidence Interval: (0.9961, 1.0459)
# 98% Confidence Interval: (0.9915, 1.0506)
# 99% Confidence Interval: (0.9915, 1.0506)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 1.021
# Model Std: 0.403
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.8574
# SPY Std: 0.9776
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 53
# --------------------------------------------------
# 90% Confidence Interval: (27.13, 44.4639)
# 95% Confidence Interval: (25.4697, 46.1243)
# 98% Confidence Interval: (23.5392, 48.0548)
# 99% Confidence Interval: (23.5392, 48.0548)
# --------------------------------------------------
# Model Results:
# Model Mean: 35.8%
# Model Std: 38.36%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -18.65%
# Buy/Hold Std: 11.16%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: -9.67%
# SPY Buy/Hold Std: 4.01%
# --------------------------------------------------
# --------------------------------------------------
# n = 53
# --------------------------------------------------
# 90% Confidence Interval: (0.6889, 0.8732)
# 95% Confidence Interval: (0.6713, 0.8909)
# 98% Confidence Interval: (0.6507, 0.9114)
# ...

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 272
# --------------------------------------------------
# 90% Confidence Interval: (61.791, 74.8469)
# 95% Confidence Interval: (60.5404, 76.0975)
# 98% Confidence Interval: (59.0863, 77.5516)
# 99% Confidence Interval: (59.0863, 77.5516)
# --------------------------------------------------
# Model Results:
# Model Mean: 68.32%
# Model Std: 65.45%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 32.69%
# Buy/Hold Std: 31.56%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 13.2%
# SPY Buy/Hold Std: 8.15%
# --------------------------------------------------
# --------------------------------------------------
# n = 272
# --------------------------------------------------
# 90% Confidence Interval: (0.9821, 1.0474)
# 95% Confidence Interval: (0.9758, 1.0536)
# 98% Confidence Interval: (0.9686, 1.0609)
# ...
