# %% [markdown]
# # Backtest Results

# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='SPY_1d_9-MA_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 1005
# --------------------------------------------------
# 90% Confidence Interval: (4.7087, 5.4491)
# 95% Confidence Interval: (4.6377, 5.5201)
# 98% Confidence Interval: (4.5553, 5.6025)
# 99% Confidence Interval: (4.5553, 5.6025)
# --------------------------------------------------
# Model Results:
# Model Mean: 5.08%
# Model Std: 7.14%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 9.34%
# Buy/Hold Std: 16.93%
# --------------------------------------------------

# %%
sharpe_hist(import_csv,buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# n = 1005
# --------------------------------------------------
# 90% Confidence Interval: (0.6135, 0.6769)
# 95% Confidence Interval: (0.6075, 0.6829)
# 98% Confidence Interval: (0.6004, 0.69)
# 99% Confidence Interval: (0.6004, 0.69)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.6452
# Model Std: 0.6103
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 0.8111
# Buy/Hold Std: 0.9558
# --------------------------------------------------

# %%
bear_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is down
# --------------------------------------------------
# --------------------------------------------------
# n = 227
# --------------------------------------------------
# 90% Confidence Interval: (7.4527, 9.3345)
# 95% Confidence Interval: (7.2724, 9.5148)
# 98% Confidence Interval: (7.0629, 9.7244)
# 99% Confidence Interval: (7.0629, 9.7244)
# --------------------------------------------------
# Model Results:
# Model Mean: 8.39%
# Model Std: 8.62%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: -15.65%
# Buy/Hold Std: 10.47%
# --------------------------------------------------
# --------------------------------------------------
# n = 227
# --------------------------------------------------
# 90% Confidence Interval: (0.6303, 0.7494)
# 95% Confidence Interval: (0.6188, 0.7609)
# 98% Confidence Interval: (0.6056, 0.7741)
# 99% Confidence Interval: (0.6056, 0.7741)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.6898
# Model Std: 0.5459
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: -0.5436
# Buy/Hold Std: 0.3884
# --------------------------------------------------

# %%
bull_hist(import_csv, buy_hold=True, spy=True)
# Out:
# --------------------------------------------------
# How Model Performs while asset is up
# --------------------------------------------------
# --------------------------------------------------
# n = 778
# --------------------------------------------------
# 90% Confidence Interval: (3.7386, 4.4849)
# 95% Confidence Interval: (3.6671, 4.5564)
# 98% Confidence Interval: (3.584, 4.6395)
# 99% Confidence Interval: (3.584, 4.6395)
# --------------------------------------------------
# Model Results:
# Model Mean: 4.11%
# Model Std: 6.33%
# --------------------------------------------------
# Buy/Hold Results:
# Buy/Hold Mean: 16.63%
# Buy/Hold Std: 10.14%
# --------------------------------------------------
# --------------------------------------------------
# n = 778
# --------------------------------------------------
# 90% Confidence Interval: (0.5952, 0.6692)
# 95% Confidence Interval: (0.5881, 0.6763)
# 98% Confidence Interval: (0.5798, 0.6845)
# 99% Confidence Interval: (0.5798, 0.6845)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 0.6322
# Model Std: 0.6276
# --------------------------------------------------
# Buy/Hold Sharpe:
# Buy/Hold Mean: 1.2064
# Buy/Hold Std: 0.6663
# --------------------------------------------------
